# %%
import pandas as pd

# reading csv file 
df = pd.read_csv("/Users/oshadura/Downloads/QI1120469_SHDKSN88S50Z138X/QI_1120469_1_20241_VALORI.csv", sep=';')
df
# Out:
#                                                                                                                                                                                                                                      Quotazioni Immobiliari : Valori di Mercato - Semestre 2024/1 - elaborazione del 03-GEN-25
# Area_territoriale Regione Prov Comune_ISTAT Comune_cat Sez Comune_amm Comune_descrizione Fascia Zona LinkZona   Cod_Tip Descr_Tipologia              Stato   Stato_prev Compr_min Compr_max Sup_NL_compr Loc_min Loc_max Sup_NL_loc                                                NaN
# CENTRO            TOSCANA SI   9052028      I9BH           H875       SAN GIMIGNANO      B      B1   SI00000493 20      Abitazioni civili            NORMALE P          2300      3400      L            7,3     10,6    L                                                         NaN
# ...
